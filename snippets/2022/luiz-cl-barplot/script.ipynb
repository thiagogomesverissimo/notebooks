# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data.csv', index_col=0)
df
# Out:
#                      Ciente do objetivo deste questionário, você concorda em participar?  \
# Carimbo de data/hora
# 10/20/2022 8:31:41                                                  Sim
# 10/26/2022 15:13:33                                                 Sim
# 10/26/2022 19:34:25                                                 Sim
# 10/20/2022 0:22:40                                                  Sim
# 10/20/2022 18:52:01                                                 Sim
# ...                                                                 ...
# 10/19/2022 22:44:41                                                 Sim
# 10/20/2022 11:46:16                                                 Sim
# 10/25/2022 19:12:44                                                 Sim
# 10/19/2022 22:16:46                                                 Sim
# 10/21/2022 6:37:03                                                  Sim
#
#                      Você é das Ciências Sociais?  \
# ...

# %%
# barplot com raça, gênero e cotista
df[['raça', 'gênero', 'cotista']]
# Out:
#                         raça            gênero          cotista
# Carimbo de data/hora
# 10/20/2022 8:31:41    Branca  Mulher Cisgênero  FUVEST c/ cotas
# 10/26/2022 15:13:33   Branca  Mulher Cisgênero  FUVEST c/ cotas
# 10/26/2022 19:34:25    Parda  Mulher Cisgênero        FUVEST AC
# 10/20/2022 0:22:40     Parda  Mulher Cisgênero             SiSU
# 10/20/2022 18:52:01    Preta  Mulher Cisgênero             SiSU
# ...                      ...               ...              ...
# 10/19/2022 22:44:41   Branca   Homem Cisgênero        FUVEST AC
# 10/20/2022 11:46:16    Preta       Não Binário             SiSU
# 10/25/2022 19:12:44   Branca   Homem Cisgênero        FUVEST AC
# 10/19/2022 22:16:46   Branca  Mulher Cisgênero        FUVEST AC
# 10/21/2022 6:37:03     Parda  Mulher Cisgênero  FUVEST c/ cotas
#
# [90 rows x 3 columns]

# %%
df["gênero-raça"] = df["gênero"] + ' ' + df["raça"]

# %%
df["gênero-raça"].unique()
# Out:
# array(['Mulher Cisgênero Branca', 'Mulher Cisgênero Parda',
#        'Mulher Cisgênero Preta', 'Homem Cisgênero Branca',
#        'Não Binário Branca', 'Homem Trans Branca',
#        'Homem Cisgênero Parda', 'Não Binário Amarela',
#        'Mulher Cisgênero Amarela', 'Homem Cisgênero Preta',
#        'Não Binário Parda', 'Não Binário Preta'], dtype=object)

# %%
df['raça'].unique()
# Out:
# array(['Branca', 'Parda', 'Preta', 'Amarela'], dtype=object)

# %%
df['gênero'].unique()
# Out:
# array(['Mulher Cisgênero', 'Homem Cisgênero', 'Não Binário',
#        'Homem Trans'], dtype=object)

# %%
df['cotista'].unique()
# Out:
# array(['FUVEST c/ cotas', 'FUVEST AC', 'SiSU', 'Transferência'],
#       dtype=object)

# %%
# Exemplo:

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid")
titanic = sns.load_dataset("titanic")
ax = sns.countplot(x="class", hue="who", data=titanic)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ax = sns.countplot(x="gênero", hue="cotista", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.savefig('output/luiz.png')
plt.show()

# %%
ax = sns.countplot(x="gênero-raça", hue="cotista", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.savefig('output/luiz2.png')
plt.show()
