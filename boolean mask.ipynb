# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns',100) # VER todas colunas

df = pd.read_csv('data/nhanes_2015_2016.csv')
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
boolean_mask = df['BMXBMI']>50
boolean_mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5730    False
# 5731    False
# 5732    False
# 5733    False
# 5734    False
# Name: BMXBMI, Length: 5735, dtype: bool

# %%
df.where(boolean_mask)
# Out:
#       SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0      NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# 1      NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# 2      NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# 3      NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# 4      NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# ...    ...     ...     ...     ...     ...       ...       ...       ...
# 5730   NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# 5731   NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# 5732   NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# 5733   NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
# 5734   NaN     NaN     NaN     NaN     NaN       NaN       NaN       NaN
#
#       DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# ...

# %%
df.where(boolean_mask).dropna()
# Out:
#          SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 1465  86212.0     2.0     1.0     1.0     1.0       2.0      32.0       1.0
# 3222  89275.0     2.0     1.0     1.0     1.0       2.0      67.0       2.0
# 3567  89862.0     2.0     1.0     1.0     1.0       2.0      60.0       4.0
# 4192  90982.0     2.0     1.0     2.0     2.0       2.0      62.0       1.0
#
#       DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# 1465       1.0       3.0       4.0       4.0  31115.35      1.0     124.0
# 3222       1.0       2.0       2.0       1.0   8294.64      1.0     127.0
# 3567       1.0       4.0       1.0       2.0  22870.52      2.0     130.0
# 4192       1.0       3.0       4.0       3.0   9845.73      1.0     127.0
#
#       INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 1465      0.25   130.0    60.0   126.0    68.0  148.2  156.2    60.7    37.0
# ...

# %%
df[df['BMXBMI']>50].dropna() # igual: df.where(boolean_mask).dropna()
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 1465  86212     2.0     1.0     1.0       1         2        32         1
# 3222  89275     2.0     1.0     1.0       1         2        67         2
# 3567  89862     2.0     1.0     1.0       1         2        60         4
# 4192  90982     2.0     1.0     2.0       2         2        62         1
#
#       DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# 1465       1.0       3.0       4.0         4  31115.35        1       124
# 3222       1.0       2.0       2.0         1   8294.64        1       127
# 3567       1.0       4.0       1.0         2  22870.52        2       130
# 4192       1.0       3.0       4.0         3   9845.73        1       127
#
#       INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 1465      0.25   130.0    60.0   126.0    68.0  148.2  156.2    60.7    37.0
# ...

# %%
df[["RIAGENDR","RIDAGEYR"]]
# Out:
#       RIAGENDR  RIDAGEYR
# 0            1        62
# 1            1        53
# 2            1        78
# 3            2        56
# 4            2        42
# ...        ...       ...
# 5730         2        76
# 5731         1        26
# 5732         2        80
# 5733         1        35
# 5734         2        24
#
# [5735 rows x 2 columns]

# %%
boolean_mask_combined = (df['BMXBMI'] > 50) & (df['RIDAGEYR'] > 50)

# %%
df.where(boolean_mask_combined).dropna()
# Out:
#          SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 3222  89275.0     2.0     1.0     1.0     1.0       2.0      67.0       2.0
# 3567  89862.0     2.0     1.0     1.0     1.0       2.0      60.0       4.0
# 4192  90982.0     2.0     1.0     2.0     2.0       2.0      62.0       1.0
#
#       DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# 3222       1.0       2.0       2.0       1.0   8294.64      1.0     127.0
# 3567       1.0       4.0       1.0       2.0  22870.52      2.0     130.0
# 4192       1.0       3.0       4.0       3.0   9845.73      1.0     127.0
#
#       INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 3222      1.02   166.0    78.0   168.0    62.0  141.9  157.5    57.2    28.0
# 3567      3.06   132.0    58.0   132.0    60.0  133.6  157.0    54.2    36.5
# 4192      2.01   122.0    64.0   130.0    68.0  123.6  154.7    51.6    34.0
#
#       BMXARML  BMXARMC  BMXWAIST  HIQ210
# ...

# %%
boolean_mask_combined = df['BMXBMI'].gt(50) & df['RIDAGEYR'].gt(50)
df.where(boolean_mask_combined).dropna()
# Out:
#          SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 3222  89275.0     2.0     1.0     1.0     1.0       2.0      67.0       2.0
# 3567  89862.0     2.0     1.0     1.0     1.0       2.0      60.0       4.0
# 4192  90982.0     2.0     1.0     2.0     2.0       2.0      62.0       1.0
#
#       DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# 3222       1.0       2.0       2.0       1.0   8294.64      1.0     127.0
# 3567       1.0       4.0       1.0       2.0  22870.52      2.0     130.0
# 4192       1.0       3.0       4.0       3.0   9845.73      1.0     127.0
#
#       INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 3222      1.02   166.0    78.0   168.0    62.0  141.9  157.5    57.2    28.0
# 3567      3.06   132.0    58.0   132.0    60.0  133.6  157.0    54.2    36.5
# 4192      2.01   122.0    64.0   130.0    68.0  123.6  154.7    51.6    34.0
#
#       BMXARML  BMXARMC  BMXWAIST  HIQ210
# ...
